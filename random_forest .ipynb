# %%
import pandas as pd

# %%
dataset = pd.read_csv("Cancer_data.csv")

# %%
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
X=pd.DataFrame(dataset.iloc[:,:-1])

# %%
X=X.drop(["diagnosis"], axis=1)

# %%
X.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
Y = pd.DataFrame(dataset.iloc[:,1])

# %%
Y
# Out:
#     diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
X_train
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 197    877159        18.08         21.84          117.40     1024.0
# 177  87281702        16.46         20.11          109.30      832.9
# 440    909411        10.97         17.20           71.73      371.5
# 364   9010877        13.40         16.95           85.48      552.4
# 244    884180        19.40         23.50          129.10     1155.0
# ..        ...          ...           ...             ...        ...
# 336    897604        12.99         14.23           84.08      514.3
# 468   9113538        17.60         23.33          119.00      980.5
# 272   8910988        21.75         20.99          147.30     1491.0
# 401    904647        11.93         10.91           76.14      442.7
# 472    911384        14.92         14.93           96.45      686.9
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 197          0.07371           0.08642         0.11030              0.05778
# 177          0.09831           0.15560         0.17930              0.08866
# 440          0.08915           0.11130         0.09457              0.03613
# 364          0.07937           0.05696         0.02181              0.01473
# 244          0.10270           0.15580         0.20490              0.08886
# ..               ...               ...             ...                  ...
# 336          0.09462           0.09965         0.03738              0.02098
# 468          0.09289           0.20040         0.21360              0.10020
# 272          0.09401           0.19610         0.21950              0.10880
# 401          0.08872           0.05242         0.02606              0.01796
# 472          0.08098           0.08549         0.05539              0.03221
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 197         0.1770  ...         19.76          24.70           129.10
# 177         0.1794  ...         17.79          28.45           123.50
# 440         0.1489  ...         12.36          26.87            90.14
# 364         0.1650  ...         14.73          21.70            93.76
# 244         0.1978  ...         21.65          30.53           144.90
# ..             ...  ...           ...            ...              ...
# 336         0.1652  ...         13.72          16.91            87.38
# 468         0.1696  ...         21.57          28.87           143.60
# 272         0.1721  ...         28.19          28.18           195.90
# 401         0.1601  ...         13.80          20.14            87.64
# 472         0.1687  ...         17.18          18.22           112.00
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 197      1228.0           0.08822             0.1963           0.2535
# 177       981.2           0.14150             0.4667           0.5862
# 440       476.4           0.13910             0.4082           0.4779
# 364       663.5           0.12130             0.1676           0.1364
# 244      1417.0           0.14630             0.2968           0.3458
# ..          ...               ...                ...              ...
# 336       576.0           0.11420             0.1975           0.1450
# 468      1437.0           0.12070             0.4785           0.5165
# 272      2384.0           0.12720             0.4725           0.5807
# 401       589.5           0.13740             0.1575           0.1514
# 472       906.6           0.10650             0.2791           0.3151
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 197               0.09181          0.2369                  0.06558
# 177               0.20350          0.3054                  0.09519
# 440               0.15550          0.2540                  0.09532
# 364               0.06987          0.2741                  0.07582
# 244               0.15640          0.2920                  0.07614
# ..                    ...             ...                      ...
# 336               0.05850          0.2432                  0.10090
# 468               0.19960          0.2301                  0.12240
# 272               0.18410          0.2833                  0.08858
# 401               0.06876          0.2460                  0.07262
# 472               0.11470          0.2688                  0.08273
#
# [455 rows x 31 columns]

# %%
X_test
# Out:
#           id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19   8510426        13.54         14.36           87.46      566.3
# 519   917080        12.75         16.70           82.51      493.8
# 6     844359        18.25         19.98          119.60     1040.0
# 142   869218        11.43         17.31           73.66      398.0
# 439   909410        14.02         15.66           89.59      606.5
# ..       ...          ...           ...             ...        ...
# 436   908916        12.87         19.54           82.67      509.2
# 327   895299        12.03         17.93           76.09      446.0
# 554   924632        12.88         28.92           82.50      514.3
# 555   924934        10.29         27.61           65.67      321.4
# 503   915143        23.09         19.83          152.10     1682.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 19           0.09779           0.08129        0.066640             0.047810
# 519          0.11250           0.11170        0.038800             0.029950
# 6            0.09463           0.10900        0.112700             0.074000
# 142          0.10920           0.09486        0.020310             0.018610
# 439          0.07966           0.05581        0.020870             0.026520
# ..               ...               ...             ...                  ...
# 436          0.09136           0.07883        0.017970             0.020900
# 327          0.07683           0.03892        0.001546             0.005592
# 554          0.08123           0.05824        0.061950             0.023430
# 555          0.09030           0.07658        0.059990             0.027380
# 503          0.09342           0.12750        0.167600             0.100300
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 19          0.1885  ...         15.11          19.26            99.70
# 519         0.2120  ...         14.45          21.74            93.63
# 6           0.1794  ...         22.88          27.66           153.20
# 142         0.1645  ...         12.78          26.76            82.66
# 439         0.1589  ...         14.91          19.31            96.53
# ..             ...  ...           ...            ...              ...
# 436         0.1861  ...         14.45          24.38            95.14
# 327         0.1382  ...         13.07          22.25            82.74
# 554         0.1566  ...         13.89          35.74            88.84
# 555         0.1593  ...         10.84          34.91            69.57
# 503         0.1505  ...         30.79          23.87           211.50
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 19        711.2            0.1440             0.1773         0.239000
# 519       624.1            0.1475             0.1979         0.142300
# 6        1606.0            0.1442             0.2576         0.378400
# 142       503.0            0.1413             0.1792         0.077080
# 439       688.9            0.1034             0.1017         0.062600
# ..          ...               ...                ...              ...
# 436       626.9            0.1214             0.1652         0.071270
# 327       523.4            0.1013             0.0739         0.007732
# 554       595.7            0.1227             0.1620         0.243900
# 555       357.6            0.1384             0.1710         0.200000
# 503      2782.0            0.1199             0.3625         0.379400
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 19                0.12880          0.2977                  0.07259
# 519               0.08045          0.3071                  0.08557
# 6                 0.19320          0.3063                  0.08368
# 142               0.06402          0.2584                  0.08096
# 439               0.08216          0.2136                  0.06710
# ..                    ...             ...                      ...
# 436               0.06384          0.3313                  0.07735
# 327               0.02796          0.2171                  0.07037
# 554               0.06493          0.2372                  0.07242
# 555               0.09127          0.2226                  0.08283
# 503               0.22640          0.2908                  0.07277
#
# [114 rows x 31 columns]

# %%
Y_train
# Out:
#     diagnosis
# 197         M
# 177         M
# 440         B
# 364         B
# 244         M
# ..        ...
# 336         B
# 468         M
# 272         M
# 401         B
# 472         B
#
# [455 rows x 1 columns]

# %%
Y_test
# Out:
#     diagnosis
# 19          B
# 519         B
# 6           M
# 142         B
# 439         B
# ..        ...
# 436         B
# 327         B
# 554         B
# 555         B
# 503         M
#
# [114 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier(n_estimators = 20, criterion ='gini', random_state=1, max_depth=3)

# %%
classifier.fit(X_train, Y_train)
# Out:
# <ipython-input-16-673ec740c629>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(X_train, Y_train)
# RandomForestClassifier(max_depth=3, n_estimators=20, random_state=1)

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array(['B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M'], dtype=object)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print("Confusion Matrix: ", confusion_matrix(Y_test, y_pred))
# Out:
# Confusion Matrix:  [[69  0]
#  [ 7 38]]

# %%
print("Accuracy Score: ", accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score:  0.9385964912280702

# %%
classifier.feature_importances_
# Out:
# array([5.12496615e-04, 2.91036692e-02, 7.50967579e-04, 4.03017574e-02,
#        6.43615560e-02, 1.09168625e-02, 0.00000000e+00, 4.57771345e-02,
#        8.56034024e-02, 2.92959821e-03, 1.21775224e-03, 5.85349727e-03,
#        6.58115245e-05, 5.98099164e-03, 8.02729621e-02, 0.00000000e+00,
#        0.00000000e+00, 2.91884715e-03, 0.00000000e+00, 4.08804620e-03,
#        1.06013812e-03, 1.40725724e-01, 7.36762730e-03, 2.87994781e-02,
#        1.13719219e-01, 1.58524567e-03, 2.66362880e-02, 4.26270595e-02,
#        2.36380317e-01, 1.04036875e-02, 1.00398625e-02])

# %%
feature_imp = pd.Series(classifier.feature_importances_, index=X.columns).sort_values(ascending=False)

# %%
feature_imp
# Out:
# concave points_worst       0.236380
# radius_worst               0.140726
# area_worst                 0.113719
# concave points_mean        0.085603
# area_se                    0.080273
# area_mean                  0.064362
# concavity_mean             0.045777
# concavity_worst            0.042627
# perimeter_mean             0.040302
# radius_mean                0.029104
# perimeter_worst            0.028799
# compactness_worst          0.026636
# smoothness_mean            0.010917
# symmetry_worst             0.010404
# fractal_dimension_worst    0.010040
# texture_worst              0.007368
# perimeter_se               0.005981
# radius_se                  0.005853
# symmetry_se                0.004088
# symmetry_mean              0.002930
# concavity_se               0.002919
# smoothness_worst           0.001585
# fractal_dimension_mean     0.001218
# fractal_dimension_se       0.001060
# texture_mean               0.000751
# id                         0.000512
# texture_se                 0.000066
# compactness_mean           0.000000
# compactness_se             0.000000
# concave points_se          0.000000
# smoothness_se              0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Visualizing Important Features")
plt.show()

# %%
ch = X.loc[:0]

# %%
classifier.predict(ch)
# Out:
# array(['M'], dtype=object)

# %%
ch
# Out:
#        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                   0.1189
#
# [1 rows x 31 columns]
